# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/43/77/0287320dc4fd86ae8847bab6c34b5ec370e836a79c7b0c16680a3d9fd770/folium-0.8.3-py2.py3-none-any.whl (87kB)
#     100% |████████████████████████████████| 92kB 433kB/s ta 0:00:011
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Using cached https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from folium) (1.15.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from folium) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->folium) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/site-packages (from jinja2->folium) (1.1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.8.3

# %%
import folium
m = folium.Map(location=[37.5665, 126.9780])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain')

folium.Marker([37.5248, 126.9375], popup='<i>Mt. Hood Meadows</i>', 
icon=folium.Icon(icon='cloud')).add_to(m3)
folium.Marker([37.5311, 126.9113], popup='<b>Timberline Lodge</b>').add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = folium.Map( location=[37.5965, 126.9780], tiles='Stamen Toner')
folium.Circle(radius=100, 
location= [37.5248, 126.9375],
popup='The Waterfront', 
color='crimson', 
fill=False, 
).add_to(m4)     

#CircleMarker:파란거(면적에 이벤트) / Circle : 빨간거(선에 이벤트걸림) -> 용도에 따라.
folium.CircleMarker(                  
location=[37.5311, 126.9113], 
radius=100, 
popup='Laurelhurst Park', 
color='#3186cc', 
fill=True, 
fill_color='#3186cc' 
).add_to(m4)
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m5 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Toner')
m5.add_child(folium.LatLngPopup())    # 누르면 위도/경도
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m6 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 
m6.add_child(folium.ClickForMarker(popup="ClickPoint")) 
# 클릭할 때 마다 특정 포인트를 찍는다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m7 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

#RegularPolygonMarker : 다각형(3각,4각..8각...)

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    popup='polygon1',
    fill_color='#132b5e',
    number_of_sides=3,
    radius=5
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    popup='polygon2',
    fill_color='#45647d',
    number_of_sides=4,
    radius=10
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    popup='polygon3',
    fill_color='#769d96',
    number_of_sides=6,
    radius=15
    ).add_to(m7)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    popup='polygon4',
    fill_color='#769d96',
    number_of_sides=8,
    radius=20
    ).add_to(m7)
m7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import random

#Iterable
list_data = [10, 20, 30, 20, 15, 30, 45]

#Dicts of iterables
cat_1 = ['y1', 'y2', 'y3', 'y4']
index_1 = range(0, 21, 1)
multi_iter1 = {'index': index_1}
for cat in cat_1:
    multi_iter1[cat] = [random.randint(10, 100) for x in index_1]

cat_2 = ['y' + str(x) for x in range(0, 10, 1)]
index_2 = range(1, 21, 1)
multi_iter2 = {'index': index_2}
for cat in cat_2:
    multi_iter2[cat] = [random.randint(10, 100) for x in index_2]

# %% [markdown]
# # 위도와 경도가 있으면 다 할 수 있다

# %%
# !pip install vincent
# Out:
# Collecting vincent
#   Downloading https://files.pythonhosted.org/packages/11/bf/a12ecaa21a2e376a16de67e09f64a38a4acd95e04e5dc35ad2f13a6f0bfd/vincent-0.4.4.tar.gz
# Requirement already satisfied: pandas in c:\users\david\anaconda3\lib\site-packages (from vincent) (0.24.2)
# Requirement already satisfied: pytz>=2011k in c:\users\david\anaconda3\lib\site-packages (from pandas->vincent) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\david\anaconda3\lib\site-packages (from pandas->vincent) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\david\anaconda3\lib\site-packages (from pandas->vincent) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\david\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas->vincent) (1.12.0)
# Building wheels for collected packages: vincent
#   Building wheel for vincent (setup.py): started
#   Building wheel for vincent (setup.py): finished with status 'done'
#   Created wheel for vincent: filename=vincent-0.4.4-cp37-none-any.whl size=35175 sha256=e40b2bc965bf6e7f62b56afcfe5cdd4d69785aa7582a5062602374e18adb6cd5
#   Stored in directory: C:\Users\David\AppData\Local\pip\Cache\wheels\4c\0d\8a\65f34c765c6094a71cce3e42a49a26533eef61695e9b505f03
# Successfully built vincent
# Installing collected packages: vincent
# Successfully installed vincent-0.4.4

# %%
import vincent
bar = vincent.Bar(multi_iter1['y1'])
bar.axis_titles(x='Index', y='Value')
bar.to_json('asset/vis1.json')

# %%
line = vincent.Line(multi_iter1, iter_idx='index')
line.axis_titles(x='Index', y='Value')
line.legend(title='Categories')
line.to_json('asset/vis2.json')

# %%
scatter = vincent.Scatter(multi_iter2, iter_idx='index')
scatter.axis_titles(x='Index', y='Data Value')
scatter.legend(title='Categories')
scatter.colors(brew='Set3')
scatter.to_json('asset/vis3.json')

# %%
area = vincent.Area(list_data)
area.to_json('asset/vis4.json')

# %%
import json
m8 = folium.Map( location=[37.5665, 126.9780], tiles='Stamen Terrain') 

folium.RegularPolygonMarker(
    [37.5665, 126.9780],
    fill_color='#132b5e',
    radius=5,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis1.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.9780],
    fill_color='#45647d',
    radius=10,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis2.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.5665, 126.8780],
    fill_color='#769d96',
    radius=15,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis3.json')), width=450, height=250))
    ).add_to(m8)
folium.RegularPolygonMarker(
    [37.4665, 126.8780],
    fill_color='#769d96',
    radius=20,
    popup=folium.Popup(max_width=450).add_child(
        folium.Vega(json.load(open('vis4.json')), width=450, height=250))
    ).add_to(m8)
m8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_topo_json = open('/Users/David/Geo_Data/asset/seoul_municipalities_topo_simple.json', encoding='utf8')
seoul_topo_json = json.load(seoul_topo_json)

# %%
m9 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

# folium.GeoJson(seoul_geo_json,name='geojson').add_to(m9)

folium.TopoJson(seoul_topo_json,"objects.seoul_municipalities_geo",name='topojson').add_to(m9)
# -------------------------------------------------------------------------------------------------------

folium.LayerControl().add_to(m9)
m9

#단계구분도(hit map) 쉽게 그릴 수 있다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seoul_geo_json = open('/Users/David/Geo_Data/asset/seoul_municipalities_geo_simple.json',encoding='utf-8')
seoul_geo_json = json.load(seoul_geo_json)

# %%
m9 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

folium.GeoJson(seoul_geo_json,name='geojson').add_to(m9)

folium.TopoJson(seoul_topo_json,"objects.seoul_municipalities_geo",name='topojson').add_to(m9)
# -------------------------------------------------------------------------------------------------------

folium.LayerControl().add_to(m9)
m9

#단계구분도(hit map) 쉽게 그릴 수 있다.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # pandas 연동 가능. but..
# # 문제는: 규격이 없어서 여러 포맷 존재, 시/군/구 단위가 한계.

# %%
seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']
# Out:
# [{'arcs': [[0, 1, 2]],
#   'type': 'Polygon',
#   'properties': {'code': '11250',
#    'name': '강동구',
#    'name_eng': 'Gangdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[3, -2, 4, 5]],
#   'type': 'Polygon',
#   'properties': {'code': '11240',
#    'name': '송파구',
#    'name_eng': 'Songpa-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[6, -6, 7, 8, 9, 10]],
#   'type': 'Polygon',
#   'properties': {'code': '11230',
#    'name': '강남구',
#    'name_eng': 'Gangnam-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-9, 11, 12, 13, 14]],
#   'type': 'Polygon',
#   'properties': {'code': '11220',
#    'name': '서초구',
#    'name_eng': 'Seocho-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-13, 15, 16, 17, 18]],
#   'type': 'Polygon',
#   'properties': {'code': '11210',
#    'name': '관악구',
#    'name_eng': 'Gwanak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-14, -19, 19, 20]],
#   'type': 'Polygon',
#   'properties': {'code': '11200',
#    'name': '동작구',
#    'name_eng': 'Dongjak-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[21, 22, -20, 23, 24, 25]],
#   'type': 'Polygon',
#   'properties': {'code': '11190',
#    'name': '영등포구',
#    'name_eng': 'Yeongdeungpo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-17, 26, 27]],
#   'type': 'Polygon',
#   'properties': {'code': '11180',
#    'name': '금천구',
#    'name_eng': 'Geumcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[28, -24, -18, -28, 29]],
#   'type': 'Polygon',
#   'properties': {'code': '11170',
#    'name': '구로구',
#    'name_eng': 'Guro-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[30, -26, 31, 32]],
#   'type': 'Polygon',
#   'properties': {'code': '11160',
#    'name': '강서구',
#    'name_eng': 'Gangseo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-32, -25, -29, 33]],
#   'type': 'Polygon',
#   'properties': {'code': '11150',
#    'name': '양천구',
#    'name_eng': 'Yangcheon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[34, 35, 36, -22, -31, 37, 38]],
#   'type': 'Polygon',
#   'properties': {'code': '11140',
#    'name': '마포구',
#    'name_eng': 'Mapo-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[39, 40, -35, 41]],
#   'type': 'Polygon',
#   'properties': {'code': '11130',
#    'name': '서대문구',
#    'name_eng': 'Seodaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[42, -42, -39, 43]],
#   'type': 'Polygon',
#   'properties': {'code': '11120',
#    'name': '은평구',
#    'name_eng': 'Eunpyeong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[44, 45, 46, 47, 48]],
#   'type': 'Polygon',
#   'properties': {'code': '11110',
#    'name': '노원구',
#    'name_eng': 'Nowon-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-48, 49, 50]],
#   'type': 'Polygon',
#   'properties': {'code': '11100',
#    'name': '도봉구',
#    'name_eng': 'Dobong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-50, -47, 51, 52]],
#   'type': 'Polygon',
#   'properties': {'code': '11090',
#    'name': '강북구',
#    'name_eng': 'Gangbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[53, -52, -46, 54, 55, 56]],
#   'type': 'Polygon',
#   'properties': {'code': '11080',
#    'name': '성북구',
#    'name_eng': 'Seongbuk-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-45, 57, 58, 59, -55]],
#   'type': 'Polygon',
#   'properties': {'code': '11070',
#    'name': '중랑구',
#    'name_eng': 'Jungnang-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-56, -60, 60, 61, 62]],
#   'type': 'Polygon',
#   'properties': {'code': '11060',
#    'name': '동대문구',
#    'name_eng': 'Dongdaemun-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-59, 63, -3, -4, -7, 64, -61]],
#   'type': 'Polygon',
#   'properties': {'code': '11050',
#    'name': '광진구',
#    'name_eng': 'Gwangjin-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-62, -65, -11, 65, 66]],
#   'type': 'Polygon',
#   'properties': {'code': '11040',
#    'name': '성동구',
#    'name_eng': 'Seongdong-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-66, -10, -15, -21, -23, -37, 67]],
#   'type': 'Polygon',
#   'properties': {'code': '11030',
#    'name': '용산구',
#    'name_eng': 'Yongsan-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[-67, -68, -36, -41, 68]],
#   'type': 'Polygon',
#   'properties': {'code': '11020',
#    'name': '중구',
#    'name_eng': 'Jung-gu',
#    'base_year': '2013',
#    'style': {}}},
#  {'arcs': [[69, -57, -63, -69, -40, -43]],
#   'type': 'Polygon',
#   'properties': {'code': '11010',
#    'name': '종로구',
#    'name_eng': 'Jongno-gu',
#    'base_year': '2013',
#    'style': {}}}]

# %%
data = pd.DataFrame.from_dict(seoul_geo_json['features']).properties
# data = pd.DataFrame.from_dict(seoul_topo_json['objects']['seoul_municipalities_geo']['geometries']).properties

# %% [markdown]
# # map, applymap, apply

# %%
keys = data[0].keys()

# %%
for i in keys:
    print(i)
# Out:
# code
# name
# name_eng
# base_year

# %%
data_list = {}
for key in keys:
    temp_list = []
    for inst in data:
        temp_list.append(inst[key])
    data_list[key] = temp_list

# %%
data_list.keys()
# Out:
# dict_keys(['code', 'name', 'name_eng', 'base_year'])

# %%
seoul_df = pd.DataFrame.from_dict(data_list)

seoul_df
# Out:
#      code  name         name_eng base_year
# 0   11250   강동구      Gangdong-gu      2013
# 1   11240   송파구        Songpa-gu      2013
# 2   11230   강남구       Gangnam-gu      2013
# 3   11220   서초구        Seocho-gu      2013
# 4   11210   관악구        Gwanak-gu      2013
# 5   11200   동작구       Dongjak-gu      2013
# 6   11190  영등포구  Yeongdeungpo-gu      2013
# 7   11180   금천구     Geumcheon-gu      2013
# 8   11170   구로구          Guro-gu      2013
# 9   11160   강서구       Gangseo-gu      2013
# 10  11150   양천구     Yangcheon-gu      2013
# 11  11140   마포구          Mapo-gu      2013
# 12  11130  서대문구     Seodaemun-gu      2013
# 13  11120   은평구     Eunpyeong-gu      2013
# 14  11110   노원구         Nowon-gu      2013
# 15  11100   도봉구        Dobong-gu      2013
# 16  11090   강북구       Gangbuk-gu      2013
# 17  11080   성북구      Seongbuk-gu      2013
# 18  11070   중랑구      Jungnang-gu      2013
# 19  11060  동대문구    Dongdaemun-gu      2013
# 20  11050   광진구      Gwangjin-gu      2013
# 21  11040   성동구     Seongdong-gu      2013
# 22  11030   용산구       Yongsan-gu      2013
# 23  11020    중구          Jung-gu      2013
# 24  11010   종로구        Jongno-gu      2013

# %%
seoul_df.to_csv('seoul_geo_df.csv')

# %%
m10 = folium.Map( location=[37.5665, 126.9780], tiles='Mapbox Bright') 

seoul_geo_df = pd.read_csv('asset/seoul_geo_df.csv')
m10.choropleth(
    geo_data=seoul_geo_json,   #지도 표시영역.json
    name='choropleth',           
    data=seoul_geo_df,         #pandas DataFrame
    columns=['name', 'code'],  #컬럼 뭐 쓸지 [key:feature.properties.name, value]
    key_on='feature.properties.name',
    fill_color='YlGn',    #색깔
    fill_opacity=0.7,     #투명도
    line_opacity=0.2,     
    legend_name='Seoul_choropleth'  #범례
)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
m10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
