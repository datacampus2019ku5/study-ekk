# %% [markdown]
# # 영상 및 자연어 처리 분야 인공지능 기술 동향 및 전망
# - 주재걸 교수님(고려대학교 컴퓨터학과)

# %% [markdown]
# ## Deep Learning :
# - 신경망을 흉내내어 만든 머신러닝-인공신경망
#
# ## 인공지능 - 머신러닝 - 딥러닝
# - 차이:
# > 인공지능(AI) : 분야를 포괄하는 개념. 사람이 갖고있는 '지능'을 컴퓨터로 모사, 인간 대체를 표방.
# - (ex: 마이클 조던의 코트 상 위치를 추적_인공적으로,자동적으로 )
# -(인공지능이지만 머신러닝이 아닌 것: 전문가 시스템_ifelse문노가다)
#
# > 기계학습: 반복적인 학습. 주어야 하는 정보나 자료가 있고(Training Data), 주어지는 입력으로부터 얻고 싶은 Output과의 Pair(input-output) 모듈의 알고리즘을 '외주'를 통해 갖고온다.
# - 입력,출력과의 관계가 중요. (ex: Regression, Random-forest 등등...)
# - (ex: 인공신경망: 여러Layer를 Neural삼아 이용. CNN, RNN...)
#
# > 딥러닝
#
#
#
# ## 특징
# > Deep Learning : Hungry한 면이 있다.
# - ex: 조던은 x 위치에는 a, y위치에는 b, .... 학습데이터에 대한 노가다성이 짙다.
# - 학습데이터가 많으면 많을수록 성능이 100%에 가까운, 거의 완벽함에 가까워진다.
#
# > Deep Learning 성공 요인: 1. 성능 2. HW: GPU 3. Algorithm 요소
#
# - playground.tensorflow.org
# - ReLU / tanh / sigmoid / Linear 차이. (성능상 ReLU가 우수함.)
#
# > Overfitting 방지 : Dropout, Regularization
#
# > 최적화 기법: Gradient Descent
#
#
#
# ## 기계학습의 기본 세팅
# > Data item(100명의 환자)  -> 학습데이터 / 테스트 데이터로 분리
# >
#
#
#
# - Batch norm
#
# step1. training data를 평균0과 분산1로 만든다.
# step2.
#
# # Computer Vision
#
# > 웬만한 시각계열(사진)은 이제 완성되어간다.
# > 그래서 도전하는 것이 입출력 반대로.(ex: 영->한 ==> 한->영)
# - ex: '남자' 찾으려고 축약하던 것을, '남자' 로부터 불려간다.
#
# "Difference of Deep Learning from Existing Machine Learning" -by goodfellow
#
# "Are deep neural nets "software 2.0 ?""  -Google image
#
#
#
# # 딥러닝 분야
# - 영상인식 : 사람보다 뛰어남
# - 자연어 처리(NLP) : 기계번역, 대화시스템(챗봇?)
# - 음성인식 : text-to-speech, 화자인식, 노이즈캔슬링
# - 게임 인공지능 : 바둑, 스타크래프트
# - 의료 : 질병 자동 진단
# - 법률 : 판결 예측
# - 금융 : 주식 예측, 자산 관리 및 투자
#
#
#
# > 재밌는 Application : neuralTalk
# > Image Captioning
#
#
# # 인공지능 연구 최신 동향
# - 데이터 생성 및 변환 모델
# - 벡터 표현형을 통한 이종 데이터의 통합 및 변환(영상-자연어-소리/음성-기타 정형 데이터)
# - 비지도 및 자가지도 학습(self-supervised learning)
# =>Computer vision:colorization, jigsaw puzzle
# =>language model: BERT, GPT2(xLNet)
#
# > 실제 활용될 때의 이슈들
# - 인공지능 모델의 해석 가능성
# - 인공지능 모델의 취약점 및 보안
# - UI
#
#
# > https://paintschainer.preferred.tech/index_en.html
#
#
# > youtube 'Jaegul Choo'
